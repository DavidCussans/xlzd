# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/VNA_Measurements/rg316/rg316_100metres_librevna_two-1m-cables-_1M_500M_1024pts.csv',header=0)

# %%
print(df.to_string())
# Out:
#       Frequency  S11_Magnitude  S11_Magnitude (linear)   S11_Phase  S11_Unwrapped Phase  S12_Magnitude  S12_Magnitude (linear)   S12_Phase  S12_Unwrapped Phase  S21_Magnitude  S21_Magnitude (linear)   S21_Phase  S21_Unwrapped Phase  S22_Magnitude  S22_Magnitude (linear)   S22_Phase  S22_Unwrapped Phase  Unnamed: 17
# 0       1000000     -25.015432                0.056134  -41.225293           -41.225293      -5.039323                0.559801  168.993573           168.993573      -5.096961                0.556099  169.783077           169.783077     -24.517369                0.059447  -41.629932           -41.629932          NaN
# 1       1487781     -18.450549                0.119529  -71.929132           -71.929132      -5.778402                0.514138   84.389147            84.389147      -5.736572                0.516620   85.166454            85.166454     -18.475441                0.119187  -71.046361           -71.046361          NaN
# ...

# %%
x = df['Frequency']

# %%
print(x)
# Out:
# 0         1000000
# 1         1487781
# 2         1975562
# 3         2463343
# 4         2951124
#           ...
# 1019    498048875
# 1020    498536656
# 1021    499024437
# 1022    499512218
# 1023    500000000
# Name: Frequency, Length: 1024, dtype: int64

# %%
y = df['S21_Magnitude']

# %%
ax = plt.gca()
#ax.set_xlim([0.0,400e6])
#ax.set_ylim([-80.0,0])
plt.plot(x,y)
plt.grid()
