# %%
# !pip install scikit-rf
# Out:
# Collecting scikit-rf
#   Downloading scikit_rf-1.9.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: numpy>=1.21 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from scikit-rf) (2.3.5)
# Requirement already satisfied: scipy>=1.7 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from scikit-rf) (1.16.3)
# Requirement already satisfied: pandas>=1.1 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from scikit-rf) (2.3.3)
# Requirement already satisfied: typing-extensions in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from scikit-rf) (4.15.0)
# Collecting pre-commit>=3.5.0 (from scikit-rf)
#   Downloading pre_commit-4.5.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from pandas>=1.1->scikit-rf) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from pandas>=1.1->scikit-rf) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from pandas>=1.1->scikit-rf) (2025.2)
# Collecting cfgv>=2.0.0 (from pre-commit>=3.5.0->scikit-rf)
#   Downloading cfgv-3.5.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting identify>=1.0.0 (from pre-commit>=3.5.0->scikit-rf)
#   Downloading identify-2.6.15-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting nodeenv>=0.11.1 (from pre-commit>=3.5.0->scikit-rf)
#   Downloading nodeenv-1.9.1-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from pre-commit>=3.5.0->scikit-rf) (6.0.3)
# Collecting virtualenv>=20.10.0 (from pre-commit>=3.5.0->scikit-rf)
#   Downloading virtualenv-20.35.4-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six>=1.5 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1->scikit-rf) (1.17.0)
# Collecting distlib<1,>=0.3.7 (from virtualenv>=20.10.0->pre-commit>=3.5.0->scikit-rf)
#   Downloading distlib-0.4.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock<4,>=3.12.2 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=3.5.0->scikit-rf) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\phdgc\appdata\local\anaconda3\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=3.5.0->scikit-rf) (4.5.0)
# Downloading scikit_rf-1.9.0-py3-none-any.whl (620 kB)
#    ---------------------------------------- 0.0/621.0 kB ? eta -:--:--
#    ---------------------------------------- 621.0/621.0 kB 8.8 MB/s  0:00:00
# Downloading pre_commit-4.5.0-py2.py3-none-any.whl (226 kB)
# Downloading cfgv-3.5.0-py2.py3-none-any.whl (7.4 kB)
# Downloading identify-2.6.15-py2.py3-none-any.whl (99 kB)
# Downloading nodeenv-1.9.1-py2.py3-none-any.whl (22 kB)
# Downloading virtualenv-20.35.4-py3-none-any.whl (6.0 MB)
#    ---------------------------------------- 0.0/6.0 MB ? eta -:--:--
#    ---------------------------------------- 6.0/6.0 MB 30.7 MB/s  0:00:00
# Downloading distlib-0.4.0-py2.py3-none-any.whl (469 kB)
# Installing collected packages: distlib, virtualenv, nodeenv, identify, cfgv, pre-commit, scikit-rf
#
#    ---------------------------------------- 0/7 [distlib]
#    ---------------------------------------- 0/7 [distlib]
#    ---------------------------------------- 0/7 [distlib]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----- ---------------------------------- 1/7 [virtualenv]
#    ----------- ---------------------------- 2/7 [nodeenv]
#    ----------- ---------------------------- 2/7 [nodeenv]
#    ----------------- ---------------------- 3/7 [identify]
#    ----------------- ---------------------- 3/7 [identify]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------- ----------- 5/7 [pre-commit]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------- ----- 6/7 [scikit-rf]
#    ---------------------------------------- 7/7 [scikit-rf]
#
# Successfully installed cfgv-3.5.0 distlib-0.4.0 identify-2.6.15 nodeenv-1.9.1 pre-commit-4.5.0 scikit-rf-1.9.0 virtualenv-20.35.4

# %%
# import pandas as pd
import matplotlib.pyplot as plt
import skrf

xlzdDirectory = '../data/VNA_Measurements/rg316'
#rg316_100metres = skrf.Network('C:/Users/phdgc/OneDrive - University of Bristol/XLZD/VNA Measurements/rg316/rg316_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p.s2p')
rg316_100metres = skrf.Network( xlzdDirectory + '/rg316_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p.s2p')
rg316_specification = skrf.Network( xlzdDirectory + '/tasker_rg316_data.s1p')
rg400_specification = skrf.Network(xlzdDirectory + '/awc_rg400_data.s1p')
rg400_data_50metres = skrf.Network(xlzdDirectory + '/habia_rg400_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p.s2p') 
rg400_data_100metres = rg400_data_50metres ** rg400_data_50metres
# df = pd.read_csv('C:/Users/phdgc/OneDrive - University of Bristol/XLZD/VNA Measurements/rg316/rg316_100metres_librevna_two-1m-cables-_1M_500M_1024pts.csv',header=0)

# %%
rg316_100metres
# Out:
# 2-Port Network: 'rg316_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p',  0.001-0.5 GHz, 1024 pts, z0=[50.+0.j 50.+0.j]

# %%
fig, ax = plt.subplots()

# %%
rg316_100metres_plt = rg316_100metres.plot_s_db(n=0,m=1)
rg316_specification.plot_s_db(ax=rg316_100metres_plt)
rg400_specification.plot_s_db(ax=rg316_100metres_plt)
rg400_data_100metres.plot_s_db(ax=rg316_100metres_plt,n=0,m=1)
#rg316_100metres_plt.set_xlim([0,0.5])
plt.xlim([0,0.5e9])
plt.ylim([-80,0])
# Out:
# (-80, 0)

# %%
rg400_data_100metres
# Out:
# 2-Port Network: 'habia_rg400_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p',  0.001-0.5 GHz, 1024 pts, z0=[50.+0.j 50.+0.j]

# %%
rg316_specification.plot_s_db()
