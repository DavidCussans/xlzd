# %%
# import pandas as pd
# import matplotlib.pyplot as plt
import skrf

xlzdDirectory = 'C:/Users/phdgc/OneDrive - University of Bristol/XLZD/VNA Measurements/rg316'
#rg316_100metres = skrf.Network('C:/Users/phdgc/OneDrive - University of Bristol/XLZD/VNA Measurements/rg316/rg316_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p.s2p')
rg316_100metres = skrf.Network( xlzdDirectory + '/rg316_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p.s2p')
rg316_specification = skrf.Network( xlzdDirectory + '/tasker_rg316_data.s1p')
rg400_specification = skrf.Network(xlzdDirectory + '/awc_rg400_data.s1p')
rg400_data_100metres = skrf.Network(xlzdDirectory + '/habia_rg400_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p.s2p')
# df = pd.read_csv('C:/Users/phdgc/OneDrive - University of Bristol/XLZD/VNA Measurements/rg316/rg316_100metres_librevna_two-1m-cables-_1M_500M_1024pts.csv',header=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 10
#       8 rg316_specification = skrf.Network( xlzdDirectory + '/tasker_rg316_data.s1p')
#       9 rg400_specification = skrf.Network(xlzdDirectory + '/awc_rg400_data.s1p')
# ---> 10 rg400_data_100metres = skrf.Network(xlzdDirectory + '/habia_rg400_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\skrf\network.py:437, in Network.__init__(self, file, name, params, comments, f_unit, s_def, **kwargs)
#     432     self.read_touchstone(file, self.encoding)
#     434 else:
#     435     # open file in 'binary' mode because we are going to try and
#     436     # unpickle it first
# --> 437     fid = get_fid(file, 'rb')
#     439     try:
#     440         self.read(fid)
#
# ...

# %%
rg316_100metres
# Out:
# 2-Port Network: 'rg316_100metres_librevna_two-1m-cables_1M_500M_1024pts.s1p',  0.001-0.5 GHz, 1024 pts, z0=[50.+0.j 50.+0.j]

# %%
rg316_100metres_plt = rg316_100metres.plot_s_db(n=0,m=1)
rg316_specification.plot_s_db(ax=rg316_100metres_plt)
#rg400_specification.plot_s_db()

# %%
rg316_specification = skrf.Network('C:/Users/phdgc/OneDrive - University of Bristol/XLZD/VNA Measurements/rg316/tasker_rg316_data.s1p')

# %%
rg316_specification.plot_s_db()

# %%
print(x)
# Out:
# 0         1000000
# 1         1487781
# 2         1975562
# 3         2463343
# 4         2951124
#           ...
# 1019    498048875
# 1020    498536656
# 1021    499024437
# 1022    499512218
# 1023    500000000
# Name: Frequency, Length: 1024, dtype: int64

# %%
y = df['S21_Magnitude']

# %%
ax = plt.gca()
#ax.set_xlim([0.0,400e6])
#ax.set_ylim([-80.0,0])
plt.plot(x,y)
plt.grid()

# %%
help(rg316_100metres.plot_s_db())
# Out:
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
